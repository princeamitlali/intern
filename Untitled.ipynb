# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('city_ranking.csv')
#schema = pd.read_csv('survey_results_schema.csv')
df.head(10)
# Out:
#             city         country  Employment Score  Startup Score  \
# 0         Berlin         Germany               4.8            9.0
# 1       Montréal          Canada               6.0            8.1
# 2         London  United Kingdom               6.6            9.8
# 3      Amsterdam     Netherlands               7.6            8.3
# 4        Toronto          Canada               6.3            9.5
# 5      Vancouver          Canada               8.5            8.7
# 6      Barcelona           Spain               2.9            7.8
# 7  New York City             USA               7.9           10.0
# 8        Cologne         Germany               1.8            3.4
# 9     Manchester  United Kingdom               5.9            3.2
#
#    Tourism Score  Housing Score  Food Ranking  Transport Score  Health Rank  \
# 0            6.2            5.2           7.2              7.1          3.9
# 1            5.7            6.4           5.1              3.6          7.4
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=20,20

# %%
num_rows = df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1]  #Provide the number of columns in the dataset
print(num_rows,num_cols)
# Out:
# 110 20

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
print(df.dtypes)
# Out:
# city                              object
# country                           object
# Employment Score                 float64
# Startup Score                    float64
# Tourism Score                    float64
# Housing Score                    float64
# Food Ranking                     float64
# Transport Score                  float64
# Health Rank                      float64
# Internet Speed Score             float64
# University Score                 float64
# Access to Contraceptive Score    float64
# Gender Equality Score            float64
# Immigration Tolerence            float64
# Personal Freedom and Choice      float64
# LGBT friendly Score              float64
# Nightlife Score                  float64
# Beer Ranking                     float64
# Festival Ranking                 float64
# Total                            float64
# dtype: object

# %%
no_nulls = set(df.columns[df.isnull().mean()==0])   #columns having zero null value
no_nulls
# Out:
# {'Access to Contraceptive Score',
#  'Beer Ranking',
#  'Employment Score',
#  'Festival Ranking',
#  'Food Ranking',
#  'Gender Equality Score',
#  'Health Rank',
#  'Housing Score',
#  'Immigration Tolerence',
#  'Internet Speed Score',
#  'LGBT friendly Score',
#  'Nightlife Score',
#  'Personal Freedom and Choice',
#  'Startup Score',
#  'Total',
#  'Tourism Score',
#  'Transport Score',
#  'University Score',
#  'city',
#  'country'}

# %%
def Plot_Graph(column_name,Title):
    '''
    INPUT - TITLE - string - title of the plot
            column_name - string - the name of the column you would like to know about
    OUTPUT - 
            plot-bar- bar plot of the column
    '''
    status_vals = df[column_name].value_counts()

    (status_vals/df.shape[0]).plot(kind="bar");
    plt.title(Title);
    plt.show();

# %%
Plot_Graph('country', "your main field of study")

# %%
Plot_Graph('city', "your main field of study")

# %%
Plot_Graph('University Score', "your main field of study")

# %%
Plot_Graph( 'Transport Score', "your main field of study")

# %%
Plot_Graph( 'Tourism Score', "your main field of study")

# %%
Plot_Graph( 'Total', "your main field of study")

# %%
Plot_Graph( 'Startup Score', "your main field of study")

# %%
Plot_Graph( 'Personal Freedom and Choice', "your main field of study")

# %%
Plot_Graph( 'Nightlife Score', "your main field of study")

# %%
Plot_Graph( 'LGBT friendly Score', "your main field of study")

# %%
Plot_Graph( 'Internet Speed Score', "your main field of study")

# %%
Plot_Graph( 'Immigration Tolerence', "your main field of study")

# %%
Plot_Graph( 'Housing Score', "your main field of study")

# %%
Plot_Graph( 'Health Rank', "your main field of study")

# %%
Plot_Graph( 'Gender Equality Score', "your main field of study")

# %%
Plot_Graph( 'Food Ranking', "your main field of study")

# %%
Plot_Graph( 'Festival Ranking', "your main field of study")

# %%
Plot_Graph( 'Employment Score', "your main field of study")

# %%
Plot_Graph( 'Beer Ranking', "your main field of study")

# %%
Plot_Graph( 'Access to Contraceptive Score', "your main field of study")

# %%
def count_freq_for_each(column_name):
    '''
    INPUT - column_name - string - the name of the column you would like to know about
    
    OUTPUT - result - string - the count pf indivisual in the column
    '''
    result = (df[column_name].value_counts())
    return result

# %%
count_freq_for_each('country')
# Out:
# USA               12
# France             8
# United Kingdom     7
# Australia          6
# Germany            5
# Spain              5
# Netherlands        5
# Canada             5
# Italy              4
# Mexico             3
# New Zealand        3
# Switzerland        3
# Austria            3
# Belgium            3
# China              2
# Israel             2
# Czech Republic     2
# Norway             2
# Brazil             2
# Sweden             2
# Portugal           2
# Ireland            2
# Colombia           2
# Japan              2
# Thailand           1
# Peru               1
# Poland             1
# Denmark            1
# Singapore          1
# South Korea        1
# Chile              1
# Greece             1
# Taiwan             1
# Finland            1
# Malaysia           1
# Hong Kong SAR      1
# Romania            1
# Russia             1
# Argentina          1
# South Africa       1
# Hungary            1
# Turkey             1
# Name: country, dtype: int64

# %%
count_freq_for_each('city')
# Out:
# Berlin               1
# Gothenburg           1
# Hamburg              1
# Ottawa               1
# Toulouse             1
# Lyon                 1
# Portland             1
# Québec City          1
# Christchurch         1
# Edinburgh            1
# Bucharest            1
# Cape Town            1
# Rio de Janeiro       1
# Rome                 1
# Montréal             1
# Monterrey            1
# Adelaide             1
# Miami                1
# Lille                1
# Bangkok              1
# Valencia             1
# Montpellier          1
# Utrecht              1
# Taipei               1
# Copenhagen           1
# Stockholm            1
# Barcelona            1
# Santiago de Chile    1
# Philadelphia         1
# Hong Kong            1
# Porto                1
# Glasgow              1
# Mexico City          1
# Kuala Lumpur         1
# Manchester           1
# Budapest             1
# Frankfurt            1
# Austin               1
# Canberra             1
# Madrid               1
# ...

# %%
count_freq_for_each('University Score')
# Out:
# 1.0     38
# 4.2      4
# 3.7      3
# 1.4      3
# 6.6      3
# 3.5      3
# 5.0      3
# 6.9      3
# 3.9      2
# 4.8      2
# 5.4      2
# 3.1      2
# 2.7      2
# 5.2      2
# 6.4      2
# 5.9      2
# 5.1      2
# 4.3      1
# 5.8      1
# 1.6      1
# 8.4      1
# 5.3      1
# 6.5      1
# 1.5      1
# 5.5      1
# 2.0      1
# 4.5      1
# 7.9      1
# 7.3      1
# 5.7      1
# 9.8      1
# 4.4      1
# 2.6      1
# 3.3      1
# 6.8      1
# 6.1      1
# 4.1      1
# 7.7      1
# 2.9      1
# 2.3      1
# 8.1      1
# 4.9      1
# 7.2      1
# 3.4      1
# 9.6      1
# 1.8      1
# 6.7      1
# 4.7      1
# 10.0     1
# Name: University Score, dtype: int64

# %%
count_freq_for_each('Transport Score')
# Out:
# 1.1     7
# 2.5     5
# 5.3     5
# 2.8     5
# 4.8     3
# 4.3     3
# 3.7     3
# 2.9     3
# 1.7     3
# 6.1     3
# 3.6     3
# 7.0     3
# 3.0     3
# 5.1     2
# 8.3     2
# 6.3     2
# 5.5     2
# 2.2     2
# 4.6     2
# 5.9     2
# 6.0     2
# 3.8     2
# 2.7     2
# 10.0    1
# 8.5     1
# 8.0     1
# 4.5     1
# 7.5     1
# 1.8     1
# 8.8     1
# 0.0     1
# 6.5     1
# 1.5     1
# 2.0     1
# 4.0     1
# 3.5     1
# 4.2     1
# 0.5     1
# 6.4     1
# 0.4     1
# 7.3     1
# 6.9     1
# 3.9     1
# 8.2     1
# 4.7     1
# 0.6     1
# 4.1     1
# 1.2     1
# 6.2     1
# 3.3     1
# 5.8     1
# 3.2     1
# 2.4     1
# 7.1     1
# 7.7     1
# 6.8     1
# 5.4     1
# 5.7     1
# 4.9     1
# 0.9     1
# 6.7     1
# 7.2     1
# 7.4     1
# 5.0     1
# Name: Transport Score, dtype: int64

# %%
count_freq_for_each('Tourism Score')
# Out:
# 2.8     2
# 1.7     2
# 9.4     2
# 7.2     2
# 0.6     2
# 5.0     2
# 6.1     2
# 8.3     2
# 3.9     2
# 3.2     1
# 1.3     1
# 0.2     1
# 1.6     1
# 1.1     1
# 4.7     1
# 7.4     1
# 3.3     1
# 3.1     1
# 5.3     1
# 0.8     1
# 5.9     1
# 8.7     1
# 9.7     1
# 5.1     1
# 2.3     1
# 7.1     1
# 9.2     1
# 3.4     1
# 9.6     1
# 4.9     1
# 5.7     1
# 5.5     1
# 6.0     1
# 4.0     1
# 6.5     1
# 1.0     1
# 3.0     1
# 9.5     1
# 10.0    1
# 7.5     1
# 4.5     1
# 9.0     1
# 8.0     1
# 8.5     1
# 3.5     1
# 0.0     1
# 1.5     1
# 0.5     1
# 7.0     1
# 2.0     1
# 7.8     1
# 1.9     1
# 0.3     1
# 2.7     1
# 2.1     1
# 7.3     1
# 6.3     1
# 5.4     1
# 8.1     1
# 4.2     1
# 1.2     1
# 0.9     1
# 8.8     1
# 6.7     1
# 8.4     1
# 5.8     1
# 4.8     1
# 3.7     1
# 2.2     1
# 5.2     1
# 4.3     1
# 6.9     1
# 6.2     1
# 2.9     1
# 0.4     1
# 8.9     1
# 3.6     1
# 1.8     1
# 9.8     1
# 4.1     1
# 9.1     1
# 3.8     1
# 4.6     1
# ...

# %%
count_freq_for_each('Total')
# Out:
# 5.37    3
# 4.65    3
# 4.71    2
# 5.35    2
# 4.83    2
# 5.61    2
# 5.28    2
# 5.34    2
# 5.82    2
# 4.61    2
# 5.21    2
# 4.69    2
# 4.75    2
# 4.82    2
# 5.18    2
# 5.78    2
# 5.09    2
# 5.19    2
# 5.33    2
# 5.75    2
# 5.73    1
# 7.14    1
# 3.91    1
# 4.78    1
# 6.17    1
# 5.58    1
# 4.14    1
# 5.05    1
# 5.20    1
# 3.21    1
# 4.47    1
# 4.24    1
# 5.48    1
# 5.74    1
# 5.25    1
# 5.87    1
# 6.31    1
# 5.03    1
# 5.08    1
# 4.93    1
# 6.63    1
# 6.12    1
# 5.04    1
# 4.49    1
# 3.46    1
# 4.11    1
# 4.80    1
# 5.68    1
# 4.74    1
# 5.98    1
# 6.06    1
# 4.81    1
# 5.90    1
# 5.26    1
# 6.10    1
# 3.84    1
# 4.23    1
# 5.43    1
# 5.54    1
# 3.78    1
# 4.84    1
# 4.90    1
# 3.98    1
# 4.87    1
# 5.31    1
# 3.70    1
# 4.03    1
# 4.89    1
# 6.60    1
# 7.10    1
# 5.84    1
# 6.04    1
# 4.05    1
# 5.44    1
# 4.13    1
# 4.97    1
# 6.03    1
# 4.86    1
# 6.34    1
# 4.01    1
# 5.57    1
# 4.32    1
# 4.07    1
# ...

# %%
count_freq_for_each('Startup Score')
# Out:
# 0.6     4
# 8.3     2
# 6.1     2
# 0.0     2
# 1.7     2
# 2.8     2
# 3.9     2
# 9.4     2
# 0.3     2
# 7.2     2
# 0.9     2
# 5.0     2
# 4.9     1
# 4.2     1
# 0.5     1
# 5.2     1
# 5.9     1
# 9.1     1
# 1.6     1
# 2.0     1
# 2.6     1
# 9.3     1
# 8.1     1
# 1.1     1
# 1.4     1
# 7.3     1
# 2.3     1
# 1.9     1
# 5.7     1
# 6.9     1
# 3.8     1
# 6.0     1
# 9.5     1
# 10.0    1
# 7.5     1
# 2.5     1
# 8.0     1
# 3.5     1
# 4.0     1
# 6.5     1
# 3.2     1
# 4.5     1
# 3.0     1
# 9.2     1
# 8.5     1
# 1.5     1
# 5.5     1
# 7.0     1
# 2.1     1
# 7.8     1
# 7.4     1
# 1.2     1
# 4.3     1
# 3.4     1
# 5.1     1
# 7.7     1
# 9.7     1
# 6.4     1
# 2.9     1
# 6.6     1
# 7.6     1
# 3.1     1
# 5.6     1
# 1.8     1
# 3.3     1
# 0.2     1
# 4.6     1
# 9.6     1
# 8.2     1
# 8.8     1
# 6.2     1
# 5.3     1
# 3.6     1
# 3.7     1
# 4.8     1
# 7.1     1
# 7.9     1
# 5.4     1
# 4.1     1
# 9.9     1
# 8.6     1
# 6.7     1
# 5.8     1
# ...

# %%
count_freq_for_each('Personal Freedom and Choice')
# Out:
# 3.6     7
# 4.3     7
# 7.2     5
# 0.8     4
# 6.3     4
# 6.9     4
# 8.3     4
# 6.1     3
# 2.8     3
# 8.1     3
# 0.4     3
# 8.7     3
# 5.7     3
# 1.8     2
# 5.3     2
# 5.0     2
# 7.9     2
# 1.7     2
# 1.2     2
# 3.3     2
# 5.5     2
# 3.0     2
# 9.4     2
# 9.9     1
# 3.2     1
# 2.2     1
# 7.8     1
# 2.5     1
# 2.6     1
# 9.5     1
# 7.7     1
# 9.0     1
# 2.7     1
# 3.5     1
# 2.0     1
# 1.5     1
# 6.0     1
# 0.0     1
# 9.8     1
# 1.6     1
# 5.2     1
# 0.2     1
# 0.6     1
# 5.1     1
# 6.8     1
# 0.7     1
# 2.4     1
# 1.4     1
# 2.3     1
# 0.3     1
# 9.6     1
# 9.2     1
# 9.7     1
# 6.7     1
# 9.3     1
# 9.1     1
# 2.1     1
# 4.2     1
# 0.1     1
# 10.0    1
# Name: Personal Freedom and Choice, dtype: int64

# %%
count_freq_for_each('Nightlife Score')
# Out:
# 4.7     3
# 2.2     2
# 5.1     2
# 5.0     2
# 8.3     2
# 6.1     2
# 7.2     2
# 3.9     2
# 2.8     2
# 9.4     2
# 1.7     2
# 0.2     2
# 3.6     2
# 1.9     2
# 0.6     2
# 1.6     1
# 1.0     1
# 4.0     1
# 6.9     1
# 9.6     1
# 7.7     1
# 0.0     1
# 6.8     1
# 1.4     1
# 0.9     1
# 0.7     1
# 9.3     1
# 2.7     1
# 8.6     1
# 3.1     1
# 0.8     1
# 7.1     1
# 1.5     1
# 7.3     1
# 4.5     1
# 9.5     1
# 8.0     1
# 3.5     1
# 7.0     1
# 6.0     1
# 8.5     1
# 6.5     1
# 2.5     1
# 7.5     1
# 7.4     1
# 9.0     1
# 0.5     1
# 3.0     1
# 5.5     1
# 8.1     1
# 2.4     1
# 5.4     1
# 5.7     1
# 7.6     1
# 0.1     1
# 3.4     1
# 9.2     1
# 3.3     1
# 6.3     1
# 2.1     1
# 4.6     1
# 9.7     1
# 5.6     1
# 3.2     1
# 4.4     1
# 3.8     1
# 2.9     1
# 6.6     1
# 0.4     1
# 6.7     1
# 5.3     1
# 1.8     1
# 9.8     1
# 8.4     1
# 4.3     1
# 6.2     1
# 2.6     1
# 1.1     1
# 9.1     1
# 6.4     1
# 7.8     1
# 8.9     1
# 4.2     1
# ...

# %%
count_freq_for_each('LGBT friendly Score')
# Out:
# 3.9     2
# 6.1     2
# 2.8     2
# 8.3     2
# 9.4     2
# 7.2     2
# 5.0     2
# 0.6     2
# 1.7     2
# 1.8     1
# 6.4     1
# 8.8     1
# 8.9     1
# 7.4     1
# 3.6     1
# 4.3     1
# 0.1     1
# 4.4     1
# 0.8     1
# 9.7     1
# 9.2     1
# 8.7     1
# 7.6     1
# 6.6     1
# 1.9     1
# 3.8     1
# 4.8     1
# 9.9     1
# 1.4     1
# 6.3     1
# 6.5     1
# 9.5     1
# 10.0    1
# 9.0     1
# 1.0     1
# 8.0     1
# 7.5     1
# 0.0     1
# 4.5     1
# 7.0     1
# 5.5     1
# 3.0     1
# 0.5     1
# 2.5     1
# 1.5     1
# 4.0     1
# 3.5     1
# 2.2     1
# 6.0     1
# 2.0     1
# 2.4     1
# 5.7     1
# 5.4     1
# 9.8     1
# 3.3     1
# 7.9     1
# 1.2     1
# 1.3     1
# 8.6     1
# 4.2     1
# 7.8     1
# 0.4     1
# 2.6     1
# 0.9     1
# 5.8     1
# 5.3     1
# 0.2     1
# 1.6     1
# 2.9     1
# 9.1     1
# 2.7     1
# 5.2     1
# 3.4     1
# 8.1     1
# 5.9     1
# 4.7     1
# 9.6     1
# 3.1     1
# 6.8     1
# 9.3     1
# 8.2     1
# 5.6     1
# 8.4     1
# ...

# %%
count_freq_for_each('Internet Speed Score')
# Out:
# 2.2     3
# 5.0     2
# 2.8     2
# 9.4     2
# 0.6     2
# 6.7     2
# 5.1     2
# 6.1     2
# 8.3     2
# 7.2     2
# 1.7     2
# 3.4     2
# 3.9     2
# 7.5     2
# 0.7     2
# 0.0     1
# 7.8     1
# 1.3     1
# 6.4     1
# 6.2     1
# 6.6     1
# 8.2     1
# 6.0     1
# 8.8     1
# 4.5     1
# 0.5     1
# 9.3     1
# 4.6     1
# 8.1     1
# 4.7     1
# 1.2     1
# 8.4     1
# 4.9     1
# 4.0     1
# 9.5     1
# 8.5     1
# 9.0     1
# 1.0     1
# 5.4     1
# 5.5     1
# 2.5     1
# 10.0    1
# 8.0     1
# 7.0     1
# 0.3     1
# 3.0     1
# 6.5     1
# 9.8     1
# 3.6     1
# 2.0     1
# 1.5     1
# 1.4     1
# 3.2     1
# 0.2     1
# 4.3     1
# 9.6     1
# 9.9     1
# 9.7     1
# 2.7     1
# 2.9     1
# 3.8     1
# 9.2     1
# 2.1     1
# 4.2     1
# 1.9     1
# 7.4     1
# 1.6     1
# 4.1     1
# 6.3     1
# 8.7     1
# 0.4     1
# 1.8     1
# 7.7     1
# 3.3     1
# 5.6     1
# 3.7     1
# 0.1     1
# 6.9     1
# 5.7     1
# 0.9     1
# 5.9     1
# 7.3     1
# 2.6     1
# ...

# %%
count_freq_for_each('Immigration Tolerence')
# Out:
# 8.5     17
# 7.2     14
# 8.7     10
# 7.8      6
# 9.3      6
# 9.9      5
# 8.8      5
# 8.4      5
# 6.2      4
# 6.6      3
# 10.0     3
# 7.4      3
# 4.4      3
# 2.8      2
# 1.5      2
# 7.6      2
# 9.4      2
# 5.1      2
# 4.1      2
# 9.6      2
# 2.2      2
# 1.0      1
# 0.0      1
# 3.2      1
# 0.3      1
# 2.9      1
# 0.6      1
# 5.9      1
# 2.6      1
# 8.2      1
# 6.3      1
# Name: Immigration Tolerence, dtype: int64

# %%
count_freq_for_each('Housing Score')
# Out:
# 3.9     3
# 1.7     2
# 9.4     2
# 5.0     2
# 0.6     2
# 8.3     2
# 2.8     2
# 6.1     2
# 7.2     2
# 0.2     1
# 9.3     1
# 7.7     1
# 1.3     1
# 5.4     1
# 4.7     1
# 0.3     1
# 0.8     1
# 9.1     1
# 2.6     1
# 0.1     1
# 3.7     1
# 4.6     1
# 6.6     1
# 2.3     1
# 1.4     1
# 8.7     1
# 1.9     1
# 3.4     1
# 7.8     1
# 1.1     1
# 5.7     1
# 1.5     1
# 3.5     1
# 0.0     1
# 2.5     1
# 4.5     1
# 7.5     1
# 8.5     1
# 10.0    1
# 9.0     1
# 3.0     1
# 5.5     1
# 8.0     1
# 2.0     1
# 6.5     1
# 7.0     1
# 1.0     1
# 9.5     1
# 6.0     1
# 4.0     1
# 7.3     1
# 5.6     1
# 9.7     1
# 5.9     1
# 0.9     1
# 8.4     1
# 6.8     1
# 8.8     1
# 9.6     1
# 1.8     1
# 1.2     1
# 3.6     1
# 5.3     1
# 2.2     1
# 6.7     1
# 2.4     1
# 4.1     1
# 9.8     1
# 5.2     1
# 4.3     1
# 4.8     1
# 6.9     1
# 4.2     1
# 8.1     1
# 2.9     1
# 7.9     1
# 3.1     1
# 5.8     1
# 8.9     1
# 4.9     1
# 6.4     1
# 9.2     1
# 8.2     1
# ...

# %%
count_freq_for_each('Health Rank')
# Out:
# 1.9     12
# 4.4      9
# 8.3      8
# 5.6      8
# 6.3      7
# 9.1      6
# 7.4      5
# 6.9      5
# 3.9      5
# 7.9      5
# 1.1      4
# 3.5      3
# 9.6      3
# 0.9      2
# 1.6      2
# 10.0     2
# 0.3      2
# 0.5      2
# 3.0      2
# 5.2      2
# 3.2      2
# 5.4      2
# 3.4      1
# 0.6      1
# 0.8      1
# 3.1      1
# 1.8      1
# 3.8      1
# 0.0      1
# 0.7      1
# 9.9      1
# 1.5      1
# 0.1      1
# 0.2      1
# Name: Health Rank, dtype: int64

# %%
count_freq_for_each('Gender Equality Score')
# Out:
# 7.5     13
# 4.5     12
# 5.2      9
# 3.3      8
# 7.1      7
# 5.9      5
# 5.5      5
# 7.0      5
# 2.4      4
# 4.1      3
# 5.6      3
# 6.3      3
# 8.1      3
# 10.0     2
# 3.1      2
# 9.3      2
# 5.3      2
# 2.9      2
# 2.2      2
# 1.6      2
# 4.7      2
# 8.2      2
# 4.6      1
# 3.4      1
# 1.2      1
# 7.4      1
# 4.0      1
# 0.0      1
# 5.0      1
# 6.4      1
# 3.5      1
# 9.7      1
# 3.8      1
# 3.9      1
# Name: Gender Equality Score, dtype: int64

# %%
count_freq_for_each('Food Ranking')
# Out:
# 0.6     2
# 6.1     2
# 5.0     2
# 3.9     2
# 7.2     2
# 9.5     2
# 8.3     2
# 2.8     2
# 1.7     2
# 3.6     1
# 1.6     1
# 0.1     1
# 0.9     1
# 4.7     1
# 6.4     1
# 8.4     1
# 3.7     1
# 3.4     1
# 4.1     1
# 5.4     1
# 2.4     1
# 1.1     1
# 5.1     1
# 6.6     1
# 3.8     1
# 7.6     1
# 8.2     1
# 3.3     1
# 8.1     1
# 9.6     1
# 9.8     1
# 8.5     1
# 10.0    1
# 3.0     1
# 1.0     1
# 6.0     1
# 7.0     1
# 5.5     1
# 0.0     1
# 1.5     1
# 4.0     1
# 2.5     1
# 4.2     1
# 4.5     1
# 9.0     1
# 7.5     1
# 2.0     1
# 8.0     1
# 3.5     1
# 8.8     1
# 0.5     1
# 3.1     1
# 4.6     1
# 5.9     1
# 0.7     1
# 4.3     1
# 7.3     1
# 7.9     1
# 5.7     1
# 6.8     1
# 6.2     1
# 5.3     1
# 2.7     1
# 2.6     1
# 8.9     1
# 9.3     1
# 0.3     1
# 0.4     1
# 5.2     1
# 2.9     1
# 4.8     1
# 0.2     1
# 6.3     1
# 8.6     1
# 7.4     1
# 9.9     1
# 1.3     1
# 7.7     1
# 2.2     1
# 5.6     1
# 5.8     1
# 7.1     1
# 1.9     1
# ...

# %%
count_freq_for_each('Festival Ranking')
# Out:
# 0.7     22
# 2.8     18
# 4.4     10
# 6.6     10
# 0.0      8
# 8.3      7
# 6.0      7
# 5.3      7
# 7.5      5
# 9.0      3
# 9.4      3
# 8.0      3
# 9.3      1
# 9.8      1
# 9.6      1
# 8.9      1
# 10.0     1
# 9.9      1
# 9.7      1
# Name: Festival Ranking, dtype: int64

# %%
count_freq_for_each('Employment Score')
# Out:
# 6.0     3
# 7.0     3
# 6.3     3
# 7.9     3
# 8.7     3
# 7.6     3
# 1.7     2
# 2.8     2
# 0.0     2
# 3.6     2
# 9.0     2
# 3.9     2
# 4.2     2
# 7.3     2
# 0.6     2
# 5.4     2
# 5.2     2
# 8.2     2
# 8.3     2
# 5.0     2
# 5.6     2
# 2.5     2
# 9.4     2
# 3.3     2
# 2.0     2
# 6.9     1
# 0.2     1
# 3.2     1
# 5.8     1
# 8.5     1
# 0.4     1
# 1.9     1
# 0.5     1
# 4.0     1
# 1.4     1
# 4.7     1
# 3.5     1
# 3.0     1
# 9.5     1
# 1.0     1
# 1.8     1
# 4.5     1
# 1.5     1
# 9.8     1
# 7.5     1
# 10.0    1
# 6.2     1
# 4.8     1
# 9.7     1
# 0.9     1
# 9.3     1
# 0.3     1
# 5.1     1
# 4.9     1
# 2.3     1
# 4.6     1
# 2.7     1
# 5.9     1
# 3.8     1
# 1.6     1
# 9.2     1
# 9.6     1
# 4.1     1
# 7.2     1
# 6.6     1
# 1.3     1
# 0.8     1
# 1.2     1
# 2.2     1
# 6.8     1
# 6.7     1
# 8.6     1
# 4.4     1
# 2.4     1
# 0.7     1
# 3.1     1
# 9.9     1
# 2.9     1
# 1.1     1
# Name: Employment Score, dtype: int64

# %%
count_freq_for_each('Beer Ranking')
# Out:
# 2.3     9
# 4.8     7
# 6.3     6
# 4.1     3
# 5.1     3
# 8.0     3
# 6.8     3
# 9.7     3
# 2.8     3
# 9.4     2
# 5.3     2
# 1.1     2
# 3.1     2
# 0.9     2
# 0.0     2
# 0.5     2
# 5.5     2
# 8.1     2
# 7.0     2
# 0.7     2
# 8.7     2
# 5.6     2
# 2.4     1
# 8.2     1
# 6.9     1
# 9.3     1
# 3.3     1
# 7.2     1
# 7.6     1
# 1.5     1
# 3.0     1
# 3.2     1
# 6.5     1
# 9.9     1
# 3.5     1
# 9.2     1
# 10.0    1
# 0.1     1
# 9.0     1
# 8.5     1
# 8.9     1
# 7.5     1
# 2.5     1
# 9.8     1
# 0.3     1
# 3.6     1
# 1.3     1
# 3.7     1
# 6.4     1
# 5.7     1
# 8.4     1
# 8.3     1
# 7.3     1
# 7.4     1
# 0.6     1
# 7.7     1
# 3.8     1
# 9.1     1
# 6.6     1
# 1.2     1
# 4.2     1
# 0.2     1
# 2.9     1
# 1.4     1
# 8.8     1
# 7.1     1
# Name: Beer Ranking, dtype: int64

# %%
count_freq_for_each('Access to Contraceptive Score')
# Out:
# 7.8     12
# 9.4      8
# 9.5      7
# 7.9      7
# 6.6      7
# 7.3      7
# 7.1      6
# 6.9      6
# 7.5      5
# 8.6      5
# 7.2      5
# 3.4      4
# 8.4      3
# 8.9      3
# 7.0      3
# 8.0      3
# 10.0     2
# 2.9      2
# 4.2      2
# 6.2      2
# 5.6      1
# 1.6      1
# 5.1      1
# 3.2      1
# 4.5      1
# 2.6      1
# 0.0      1
# 9.1      1
# 4.8      1
# 9.9      1
# 1.3      1
# Name: Access to Contraceptive Score, dtype: int64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2d1d6d588>,
# ...
#       dtype=object)

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f");

# %%
#df = df.drop(columns=['Total'])
df = df.drop(columns=['country'])

# %%
df.head(5)
# Out:
#         city  Employment Score  Startup Score  Tourism Score  Housing Score  Food Ranking  Transport Score  Health Rank  Internet Speed Score  University Score  Access to Contraceptive Score  Gender Equality Score  Immigration Tolerence  Personal Freedom and Choice  LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  Total
# 0     Berlin               4.8            9.0            6.2            5.2           7.2              7.1          3.9                   5.0               4.9                            6.9                    7.5                    8.4                          7.8                  9.7             10.0           7.0               8.0   7.14
# ...

# %%
y = df['city']

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(y)
# Out:
# LabelEncoder()

# %%
list(le.classes_)
# Out:
# ['Adelaide',
#  'Amsterdam',
#  'Antwerp',
#  'Athens',
#  'Auckland',
#  'Austin',
#  'Bangkok',
#  'Barcelona',
#  'Beijing',
#  'Bergen',
#  'Berlin',
#  'Bern',
#  'Birmingham',
#  'Bogotá',
#  'Bologna',
#  'Bordeaux',
#  'Boston',
#  'Brisbane',
#  'Bristol',
#  'Brno',
#  'Brugge',
#  'Brussels',
#  'Bucharest',
#  'Budapest',
#  'Buenos Aires',
#  'Canberra',
#  'Cape Town',
#  'Chicago',
#  'Christchurch',
#  'Cologne',
#  'Copenhagen',
#  'Cork',
#  'Coventry',
#  'Denver',
#  'Dublin',
#  'Edinburgh',
#  'Frankfurt',
#  'Geneva',
#  'Glasgow',
#  'Gothenburg',
#  'Granada',
#  'Graz',
#  'Groningen',
#  'Guadalajara',
#  'Hamburg',
#  'Helsinki',
#  'Hong Kong',
#  'Innsbruck',
#  'Istanbul',
#  'Jerusalem',
#  'Kuala Lumpur',
#  'Lille',
#  'Lima',
#  'Lisbon',
#  'London',
#  'Los Angeles',
#  'Lyon',
#  'Madrid',
#  'Manchester',
#  'Marseille',
#  'Medellín',
#  'Melbourne',
#  'Mexico City',
#  'Miami',
#  'Milan',
#  'Monterrey',
#  'Montpellier',
#  'Montréal',
# ...

# %%
y_tf = le.transform(y)

# %%
list(le.inverse_transform([2, 2, 1]))
# Out:
# ['Antwerp', 'Antwerp', 'Amsterdam']

# %%
y_tf
# Out:
# array([ 10,  67,  54,   1,  99, 103,   7,  71,  29,  58,  44,  18,  85,
#          5,  75,  63,  69,  53,  38,  57,  61,  74,  12,  93,  80, 105,
#         81,   4,  55,  94,  36,  24,  62,  78,  27,  70,  23,  30,  86,
#         13, 102,   6,  34,  56,  77,  45,   2,  79,   8,  92,  33, 100,
#         50,  60,  82,  41,  46,  35,  43,  51,  84,  95,  32,  68,  88,
#          0,  21, 109,  16,  73,  65,  87,  17, 107,  97,  90, 101,  89,
#         96,  66,  98, 106,  15,  91,  48,  59, 108,  28,  40,  39,  52,
#         31,  42,  25,  19,  83,  72,  22,  76,   3,  64, 104,   9,  26,
#         47,  11,  49,  20,  37,  14])

# %%
city_id = pd.DataFrame(y_tf)

# %%
df.insert(1, "city_id", y_tf, True)

# %%
df.head(5)
# Out:
#         city  city_id  Employment Score  Startup Score  Tourism Score  Housing Score  Food Ranking  Transport Score  Health Rank  Internet Speed Score  University Score  Access to Contraceptive Score  Gender Equality Score  Immigration Tolerence  Personal Freedom and Choice  LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  Total
# 0     Berlin       10               4.8            9.0            6.2            5.2           7.2              7.1          3.9                   5.0               4.9                            6.9                    7.5                    8.4                          7.8                  9.7             10.0           7.0               8.0   7.14
# ...

# %%
x = df.drop(columns=['city'])

# %%
X_train, X_test, y_train, y_test = train_test_split(x, city_id, test_size = 0.3, random_state=42)

# %%
y_train
# Out:
#        0
# 33    78
# 55    41
# 69    73
# 28    55
# 40   102
# 5    103
# 53    60
# 62    32
# 39    13
# 35    70
# 16    69
# 104   47
# 34    27
# 67   109
# 7     71
# 43    56
# 66    21
# 73   107
# 27     4
# 19    57
# 88    40
# 93    25
# 25   105
# 8     29
# 101  104
# 49    92
# 13     5
# 77    89
# 24    80
# 3      1
# 17    53
# 38    86
# 85    59
# 6      7
# 105   11
# 95    83
# 91    31
# 54    82
# 50    33
# 98    76
# 46     2
# 83    91
# 61    95
# 106   49
# 100   64
# 41     6
# 58    43
# 48     8
# 94    19
# 57    35
# 75    90
# 32    62
# 103   26
# 59    51
# 63    68
# 107   20
# 37    30
# 29    94
# 97    22
# 1     67
# 52    50
# 21    74
# 2     54
# 23    93
# 87    28
# 99     3
# 74    97
# 86   108
# 82    15
# 109   14
# 20    61
# 60    84
# 71    87
# 14    75
# 92    42
# 51   100
# 102    9

# %%
lm_model = LinearRegression()
lm_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

# %%
from sklearn.cluster import KMeans

# %%
means = KMeans(n_clusters=10, random_state=0).fit(x)

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = x.index.values
cluster_map['cluster'] = means.labels_

# %%
re = cluster_map[cluster_map.cluster == 3]

# %%
re = le.inverse_transform(re['data_index'])

# %%
print(re)
# Out:
# ['Adelaide' 'Athens' 'Bangkok' 'Bogotá' 'Chicago' 'Graz' 'Hong Kong'
#  'Istanbul' 'Monterrey' 'Toronto']

# %%
pre = input()
# Out:
# Hong Kong

# %%
print(pre)
# Out:
# Hong Kong

# %%
pre_num=le.transform(pre)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-a406c8f21bc2> in <module>
# ----> 1 pre_num=le.transform(pre)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py in transform(self, y)
#     250         """
#     251         check_is_fitted(self, 'classes_')
# --> 252         y = column_or_1d(y, warn=True)
#     253         # transform of empty array is empty array
#     254         if _num_samples(y) == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape ()

# %%
price = x['city_id'].values[5]

# %%
x.head(5)
# Out:
#    city_id  Employment Score  Startup Score  Tourism Score  Housing Score  Food Ranking  Transport Score  Health Rank  Internet Speed Score  University Score  Access to Contraceptive Score  Gender Equality Score  Immigration Tolerence  Personal Freedom and Choice  LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  Total
# 0       10               4.8            9.0            6.2            5.2           7.2              7.1          3.9                   5.0               4.9                            6.9                    7.5                    8.4                          7.8                  9.7             10.0           7.0               8.0   7.14
# ...

# %%
res=df.loc[df['city'] == 'Hong Kong']
res_n=res.values

# %%
print(res_n)
# Out:
# [['Hong Kong' 46 2.2 8.3 10.0 0.3 8.4 4.8 3.2 9.2 7.3 9.9 2.4 7.6 6.0 2.7
#   5.0 3.7 5.3 5.18]]

# %%
r = np.delete(res_n,[1][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-e667577e2657> in <module>
# ----> 1 r = np.delete(res_n,[1][1])
#
# IndexError: list index out of range

# %%
print(r)
# Out:
# ['Hong Kong' 2.2 8.3 10.0 0.3 8.4 4.8 3.2 9.2 7.3 9.9 2.4 7.6 6.0 2.7 5.0
#  3.7 5.3 5.18]

# %%
r = r[1:]

# %%
print(r)
# Out:
# [46 2.2 8.3 10.0 0.3 8.4 4.8 3.2 9.2 7.3 9.9 2.4 7.6 6.0 2.7 5.0 3.7 5.3
#  5.18]

# %%
B = np.reshape(r, (-1, 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-5b1fd1c6d3fa> in <module>
# ----> 1 B = np.reshape(r, (-1, 2))
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 19 into shape (2)

# %%
y = means.predict(res_n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-d5ea2996d7d5> in <module>
# ----> 1 y = means.predict(res_n)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in predict(self, X, sample_weight)
#    1074         check_is_fitted(self, 'cluster_centers_')
#    1075
# -> 1076         X = self._check_test_data(X)
#    1077         x_squared_norms = row_norms(X, squared=True)
#    1078         return _labels_inertia(X, sample_weight, x_squared_norms,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in _check_test_data(self, X)
#     931
#     932     def _check_test_data(self, X):
# --> 933         X = check_array(X, accept_sparse='csr', dtype=FLOAT_DTYPES)
#     934         n_samples, n_features = X.shape
#     935         expected_n_features = self.cluster_centers_.shape[1]
#
# ...

# %%
from scipy.sparse import csr_matrix
#df_csr = csr_matrix(x)
item_dict ={}
for i in range(df.shape[0]):
    item_dict[(df.loc[i,'city_id'])] = df.loc[i,'city']
# dummify categorical features
# convert to csr matrix
df_csr = csr_matrix(df.drop('city', axis=1).values)

# %%
#print(df_csr)

# %%
user_book_interaction = pd.pivot_table(x, columns='city_id',values='Total')
# fill missing values with 0
user_book_interaction = user_book_interaction.fillna(0)

user_book_interaction_csr = csr_matrix(user_book_interaction.values)
user_book_interaction_csr

# %%
#print(user_id)

# %%
from lightfm import LightFM
model = LightFM(loss='warp',
                random_state=2016,
                learning_rate=0.90,
                no_components=150,
                user_alpha=0.000005)
model = model.fit(user_book_interaction_csr,
                  epochs=100,
                  num_threads=16, verbose=False)

# %%
#model.predict(x[1],np.arange(10), item_features=df_csr)

# %%
def sample_recommendation_user(model, interactions, user_id, 
                               item_dict,threshold = 0,nrec_items = 5, show = True):
    
    n_users, n_items = interactions.shape
    user_x = user_id
    scores = pd.Series(model.predict(user_x,np.arange(n_items), item_features=books_metadata_csr))
    scores.index = interactions.columns
    scores = list(pd.Series(scores.sort_values(ascending=False).index))
    
    known_items = list(pd.Series(interactions.loc[user_id,:] \
                                 [interactions.loc[user_id,:] > threshold].index).sort_values(ascending=False))
    
    scores = [x for x in scores if x not in known_items]
    return_score_list = scores[0:nrec_items]
    known_items = list(pd.Series(known_items).apply(lambda x: item_dict[x]))
    scores = list(pd.Series(return_score_list).apply(lambda x: item_dict[x]))
    if show == True:
        print ("User: " + str(user_id))
        print("Known Likes:")
        counter = 1
        for i in known_items:
            print(str(counter) + '- ' + i)
            counter+=1
        print("\n Recommended Items:")
        counter = 1
        for i in scores:
            print(str(counter) + '- ' + i)
            counter+=1

# %%
#sample_recommendation_user(model, user_book_interaction, '14.0', item_dict)
